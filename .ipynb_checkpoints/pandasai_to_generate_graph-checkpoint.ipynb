# %% [markdown]
# # PandasAI to Generate Graphs

# %%
# Ecommarce customer data & product data
import pandas as pd
ecommarce_df = pd.read_csv(r'/Users/Swapnil179353/PycharmProjects/practice/gen_ai_usecase/Ecommerce Customers.csv')
ecommarce_df.head(10)
# Out:
#                            Email  Gender  Age  \
# 0      mstephenson@fernandez.com    Male   45
# 1              hduke@hotmail.com  Female   51
# 2               pallen@yahoo.com    Male   39
# 3        riverarebecca@gmail.com    Male   46
# 4  mstephens@davidson-herman.com    Male   23
# 5         alvareznancy@lucas.biz  Female   31
# 6          katherine20@yahoo.com  Female   52
# 7             awatkins@yahoo.com    Male   52
# 8    vchurch@walter-martinez.com    Male   45
# 9               bonnie69@lin.biz    Male   43
#
#                                              Address  Avg. Session Length  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            34.497268
# 1     4547 Archer Common\nDiazchester, CA 06566-8576            31.926272
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            33.000915
# 3   1414 David Throughway\nPort Jason, OH 22070-1220            34.305557
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...            33.330673
# 5  645 Martha Park Apt. 611\nJeffreychester, MN 6...            33.871038
# 6  68388 Reyes Lights Suite 692\nJosephbury, WV 9...            32.021595
# 7              Unit 6538 Box 8980\nDPO AP 09026-4941            32.739143
# 8             860 Lee Key\nWest Debra, SD 97450-0495            33.987773
# 9              PSC 2734, Box 5255\nAPO AA 98456-7482            31.936549
#
#    Time on App  Time on Website  Length of Membership  Product Purchase ID
# 0    12.655651        39.577668              4.082621                  552
# 1    11.109461        37.268959              2.664034                  580
# 2    11.330278        37.110597              4.104543                 4696
# 3    13.717514        36.721283              3.120179                 5644
# 4    12.795189        37.536653              4.446308                 6284
# 5    12.026925        34.476878              5.493507                 6493
# 6    11.366348        36.683776              4.685017                 6726
# 7    12.351959        37.373359              4.434273                 6742
# 8    13.386235        37.534497              3.273434                 7195
# 9    11.814128        37.145168              3.202806                 7783

# %%
products_df = pd.read_csv(r'/Users/Swapnil179353/PycharmProjects/practice/gen_ai_usecase/products_list.csv')
products_df.head(10)
# Out:
#      id                                               name  \
# 0   552                          Sony Turntable - PSLX350H
# 1   580  Bose Acoustimass 5 Series III Speaker System -...
# 2  4696                             Sony Switcher - SBV40S
# 3  5644                   Sony 5 Disc CD Player - CDPCE375
# 4  6284  Bose 27028 161 Bookshelf Pair Speakers In Whit...
# 5  6493                      Denon Stereo Tuner - TU1500RD
# 6  6726          KitchenAid Pasta Roller And Cutter - KPRA
# 7  6742  Panasonic Yeast Pro Automatic Breadmaker - SDY...
# 8  7195  Sony Vertical-In-The-Ear Stereo Headphones - M...
# 9  7783   Panasonic 2-Line Integrated Telephone - KXTSC14W
#
#                                          description  price($)
# 0  Sony Turntable - PSLX350H/ Belt Drive System/ ...       780
# 1  Bose Acoustimass 5 Series III Speaker System -...       638
# 2  Sony Switcher - SBV40S/ Eliminates Disconnecti...       381
# 3  Sony 5 Disc CD Player- CDPCE375/ 5 Disc Change...       440
# 4  Bose 161 Bookshelf Speakers In White - 161WH/ ...       892
# 5  Denon Stereo Tuner - TU1500RD/ RDS Radio Data ...       381
# 6  KitchenAid Pasta Roller And Cutter - KPRA/ One...       778
# 7  Panasonic Yeast Pro Automatic Breadmaker - SDY...       612
# 8  Sony Vertical-In-The-Ear Stereo Headphones - M...       761
# 9  Panasonic 2-Line Integrated Telephone - KXTSC1...       236

# %%
from pandasai.llm.openai import OpenAI
from pandasai import PandasAI

llm = OpenAI(api_token="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")
pandas_ai = PandasAI(llm)

def pandasai_response(prompt_msg):
    response = pandas_ai([ecommarce_df,products_df], prompt=prompt_msg)
    return response

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
response = pandasai_response("""Generate total time spent on app by customer whos email is mstephenson@fernandez.com. 
give detail response in words""")
print(response)
# Out:
# The total time spent on app by customer with email mstephenson@fernandez.com is 25.3113023 hours.

# %%
response = pandasai_response("""
Let me know, app or website on which most time spent by customers.
""")
print(response)
# Out:
# The app or website on which most time was spent by customers is Website.

# %%
response = pandasai_response("""
Generate number of customers who purchase product with price between 100 to 200, 200 to 300, and so on till 900. 
generate response in dataframe
""")
print(response)
# Out:
#   Price Range Number of Customers
# 0   100 - 200                   0
# 1   200 - 300                 130
# 2   300 - 400                 143
# 3   400 - 500                 181
# 4   500 - 600                 135
# 5   600 - 700                 148
# 6   700 - 800                 148
# 7   800 - 900                 149
# 8  900 - 1000                  47

# %%
response = pandasai_response("""
Generate highest selled 5 products. 
In answer give id, total customers purchased it & total revenue generated from it. these are the only 3 columns required in output
generate response in dataframe.
""")
print(response)
# Out:
#        id  total customers purchased  total revenue generated
# 38  14715                          4                     3696
# 40  15452                          4                     3472
# 35  14061                          4                     3148
# 34  14033                          4                     3136
# 48  16669                          4                     2776

# %%
response = pandasai_response("""
Generate number of customers who purchase product with price between 100 to 200, 200 to 300, and so on till 900. 
Plot bar graph price range vs total customers
""")
print(response)
# Out:
# None

# %%
response = pandasai_response("""
Create age ranges 10 to 20, 20 to 30, etc. till 100 and total customers from each range.
Plot Doughnut charts age range vs total customers 
""")
print(response)
# Out:
# None

# %%
response = pandasai_response("""
Calculate purchasing power of gender.
Plot line chart gender vs purchasing power 
""")
print(response)
# Out:
# None

# %%
response = pandasai_response("""
Calculate purchasing power of gender & age ranges 10 to 20, 20 to 30, etc. till 100.
Plot Combo chart made up of age range vs purchasing power should be bar chart & gender should have line chart.

""")
print(response)
# Out:
# None
